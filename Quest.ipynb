# %%
import pandas as pd
import numpy as num

sharks_df = pd.read_excel('GSAF5.xls')
sharks_df.describe(include='all')

# Needs fixing / observations:
# Sex is missing in # cells (nan) nad has 8 cells
# There are names replaces by "male" and "Female"
# last two columns can be removed, (NaN as value)
# columns after 'source'

# Hipothesis
# based on initial data, There are more females attacked by sharks. However, data cleaning is neccesary to ensure this
# There are more attacks on America than other continent since they do more beach activities
# most attacks are done when surfing and are located in the USA since surfing is a more popular sport there and it as unprovoked (explore more, see what other data is relevant and why)

sharks_df.describe()
sex_series = sharks_df['Sex']
country_series = sharks_df['Country']
country_sex_activity_type_df = sharks_df[['Country','Sex','Activity','Type']]


sharks_df[500:600]
# Out:
#             Date    Year        Type       Country                  State  \
# 500  16-Mar-2019  2019.0  Unprovoked           USA                 Hawaii
# 501  12-Mar-2019  2019.0  Unprovoked           USA                Florida
# 502  05-Mar-2019  2019.0  Unprovoked           USA                 Oregon
# 503  05-Mar-2019  2019.0    Provoked  SOUTH AFRICA  Eastern Cape Province
# 504  18-Feb-2018  2019.0  Unprovoked           USA             California
# ..           ...     ...         ...           ...                    ...
# 595  24-May-2018  2018.0    Provoked     AUSTRALIA             Queensland
# 596  21-May-2018  2018.0  Unprovoked           USA         South Carolina
# 597  13-May-2018  2018.0  Unprovoked           USA         South Carolina
# 598  13-May-2018  2018.0     Invalid       ENGLAND               Cornwall
# 599     May 2018  2018.0    Provoked     AUSTRALIA      Westerm Australia
#
#                                 Location         Activity             Name  \
# 500                        Kaiwi Channel         Swimming      Eric Schall
# 501          Stuart Beach, Martin County  Boogie boarding       Kael Dewey
# 502       Cape Kiwanda, Tillamook County          Surfing  Nathan Holstedt
# 503             30 nm off Port Elizabeth          Fishing             male
# 504          Dog Beach, Huntington Beach          Surfing       Joel Smith
# ..                                   ...              ...              ...
# 595                      Cairns Aquarium   Feeding sharks             male
# 596    Isle of Palms,  Charleston County  Boogie boarding     Trey de Boer
# 597  Hilton Head Island, Beaufort County         Swimming      Jei Turrell
# 598                       Off Land's End          Fishing     Max Berryman
# 599                           Dugong Bay   Feeding sharks  Melisa Brunning
#
#     Sex  Age  ...               Species   \
# 500   M   58  ...     Cookiecutter shark
# 501   M   11  ...          Spinner shark
# 502   M  NaN  ...                    NaN
# 503   M   46  ...            2.5 m shark
# 504   M  NaN  ...         6' to 7' shark
# ..   ..  ...  ...                    ...
# 595   M   32  ...        Grey reef shark
# 596   M   10  ...                    NaN
# 597   M   10  ...                    NaN
# 598   M   21  ...       Invalid incident
# 599   F   34  ...  Tawny nurse shark, 2m
#
#                                                 Source  \
# 500                Honolulu Star Advertiser, 3/16/2019
# 501                    K. McMurray, TrackingSharks.com
# 502                                M. Michaelson, GSAF
# 503                               Times Live, 3/6/2019
# 504                                   R. Collier, GSAF
# ..                                                 ...
# 595                             ABC.net.au ,05/24/2018
# 596                                  C. Creswell, GSAF
# 597  C. Creswell, GSAF & K. McMurray TrackingSharks...
# 598                    K. McMurray, TrackingSharks.com
# 599                               Perth Now, 6/30/2018
#
#                                pdf  \
# 500          2019.03.16-Schall.pdf
# 501           2019.03.12-Dewey.pdf
# 502      2019.03.05.b-Holstedt.pdf
# 503     2019.03.05.a-Fisherman.pdf
# 504           2019.02.18-Smith.pdf
# ..                             ...
# 595  2018.05.24-CairnsAquarium.pdf
# 596          2018.05.21-deBoer.pdf
# 597       2018.05.13.b-Turrell.pdf
# 598      2018.05.13.a-Berryman.pdf
# 599        2018.05.00-Brunning.pdf
#
#                                           href formula  \
# 500  http://sharkattackfile.net/spreadsheets/pdf_di...
# 501  http://sharkattackfile.net/spreadsheets/pdf_di...
# 502  http://sharkattackfile.net/spreadsheets/pdf_di...
# 503  http://sharkattackfile.net/spreadsheets/pdf_di...
# 504  http://sharkattackfile.net/spreadsheets/pdf_di...
# ..                                                 ...
# 595  http://sharkattackfile.net/spreadsheets/pdf_di...
# 596  http://sharkattackfile.net/spreadsheets/pdf_di...
# 597  http://sharkattackfile.net/spreadsheets/pdf_di...
# 598  http://sharkattackfile.net/spreadsheets/pdf_di...
# 599  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href   Case Number  \
# 500  http://sharkattackfile.net/spreadsheets/pdf_di...    2019.03.16
# 501  http://sharkattackfile.net/spreadsheets/pdf_di...    2019.03.12
# 502  http://sharkattackfile.net/spreadsheets/pdf_di...  2019.03.05.b
# 503  http://sharkattackfile.net/spreadsheets/pdf_di...  2019.03.05.a
# 504  http://sharkattackfile.net/spreadsheets/pdf_di...    2019.02.18
# ..                                                 ...           ...
# 595  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.24
# 596  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.21
# 597  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.13.b
# 598  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.13.a
# 599  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.00
#
#     Case Number.1 original order Unnamed: 21 Unnamed: 22
# 500    2019.03.16         6418.0         NaN         NaN
# 501    2019.03.12         6417.0         NaN         NaN
# 502  2019.03.05.b         6416.0         NaN         NaN
# 503  2019.03.05.a         6415.0         NaN         NaN
# 504    2019.02.18         6414.0         NaN         NaN
# ..            ...            ...         ...         ...
# 595    2018.05.24         6323.0         NaN         NaN
# 596    2018.05.21         6322.0         NaN         NaN
# 597  2018.05.13.b         6321.0         NaN         NaN
# 598  2018.05.13.a         6320.0         NaN         NaN
# 599    2018.05.00         6319.0         NaN         NaN
#
# [100 rows x 23 columns]

# %%
print(country_series.nunique())
country_series.unique()
print(country_series.value_counts())
# Out:
# 224
# Country
# USA                               2535
# AUSTRALIA                         1473
# SOUTH AFRICA                       596
# NEW ZEALAND                        143
# PAPUA NEW GUINEA                   136
#                                   ...
# FEDERATED STATES OF MICRONESIA       1
# Maldives                             1
# RED SEA                              1
# South Africa                         1
# CEYLON (SRI LANKA)                   1
# Name: count, Length: 224, dtype: int64

# %%
sex_series.nunique() # 8 instead of 2
# Out:
# 8

# %%
sex_series.unique() # Needs fixing - M x 2 means 2 men rows? what N means
# Out:
# array(['F', 'M', nan, ' M', 'M ', 'lli', 'M x 2', 'N', '.'], dtype=object)

# %%
sex_series.value_counts() # More males
# Out:
# Sex
# M        5561
# F         772
# M           2
# N           2
#  M          1
# lli         1
# M x 2       1
# .           1
# Name: count, dtype: int64

# %%
country_sex_activity_df.value_counts() # Surfing, male, and USA - 578
# Out:
# Country    Sex  Activity
# USA        M    Surfing                                               578
#                 Swimming                                              256
# AUSTRALIA  M    Surfing                                               221
#                 Swimming                                              155
# USA        M    Fishing                                               121
#                                                                      ...
# INDIA      M    Swimming or surfing                                     1
#                 Standing                                                1
#                 Ship lay at anchor & man was working on its rudder      1
#                 Murder                                                  1
# YEMEN      M    Swimming at side of small boat                          1
# Name: count, Length: 2189, dtype: int64

# %%
country_sex_activity_type_df.value_counts()
# Out:
# Country       Sex  Activity                          Type
# USA           M    Surfing                           Unprovoked      547
#                    Swimming                          Unprovoked      232
# AUSTRALIA     M    Surfing                           Unprovoked      208
#                    Swimming                          Unprovoked      132
# SOUTH AFRICA  M    Surfing                           Unprovoked       97
#                                                                     ...
# INDIA         M    Washing a dog                     Unprovoked        1
#                    Washed off catamaran in the surf  Unprovoked        1
#                    The Dwarka foundered              Sea Disaster      1
#                    Swimming or surfing               Unprovoked        1
# YEMEN         M    Swimming at side of small boat    Unprovoked        1
# Name: count, Length: 2398, dtype: int64

# %%
# EMPEZAR ACA

# read file
df = pd.read_excel('GSAF5.xls')

# rename columns
df.columns = df.columns.str.strip().str.replace(" ", "_").str.lower()

# remove last two columns (NaN in all)
#df = df.drop(['unnamed:_21','unnamed:_22'],axis=1)

# country, activity, Type
#hip_vars_df = df[['country','activity','type']]


df['country'] = df['country'].str.lower().str.strip() # YO limpiar

# %%
activity_values = df['activity'].unique() # limpiar Jose
activity_values

# %%
type_values = df['type'].unique() # limpiar Jose
type_values
